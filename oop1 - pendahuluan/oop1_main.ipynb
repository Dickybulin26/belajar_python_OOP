# %% [markdown]
# ### **OOP Kelas Terbuka #1 - Pendahuluan**

# %%
class Hero: #* template
    pass


hero1 = Hero() #* instansiasi objek
hero2 = Hero() #* instansiasi objek
hero3 = Hero() #* instansiasi objek

# %%
hero1.name = 'sniper'
hero1.helth = 100

# %%
hero2.name = 'sven'
hero2.helth = 100

# %%
hero3.name = 'ucup'
hero3.helth = 100

# %%
print(hero1)
print(hero1.__dict__)
print(hero1.name)
# Out:
# ...
# {'name': 'sniper', 'helth': 100}
# sniper
