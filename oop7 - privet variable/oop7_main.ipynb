# %% [markdown]
# ### **OOP Kelas Terbuka #7 - Private Variable**

# %%
class Hero:

    #* class variable
    jumlah = 0 
    __privateJumlah = 0

    def __init__(self, name, health):
        self.name = name
        self.health = health

        '''
        variable instance private

        kalo di bahasa java menggunakan privet 
        contoh: private namaVar
        '''

        self.__private = "ini Private"

        '''
        variable instance private

        kalo di bahasa java menggunakan privet 
        contoh: protected namaVar
        '''

        self._protected = 'ini Protected'

lina = Hero('lina', 100)

# %%
print(lina.__dict__)
print(Hero.__dict__)
# print(Hero.__privateJumlah)
# Out:
# {'name': 'lina', 'health': 100, '_Hero__private': 'ini Private', '_protected': 'ini Protected'}
# {'__module__': '__main__', 'jumlah': 0, '_Hero__privateJumlah': 0, '__init__': <function Hero.__init__ at 0x00000296F6256DD0>, '__dict__': <attribute '__dict__' of 'Hero' objects>, '__weakref__': <attribute '__weakref__' of 'Hero' objects>, '__doc__': None}
