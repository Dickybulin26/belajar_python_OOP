# %% [markdown]
# ### **OOP Kelas Terbuka #16.1 - Multiple Inheritance**

# %%
class A:

  def method_A(self):
    print('ini adalah method A')

class B:
  
  def method_B(self):
    print('ini adalah method B')

class C(A,B):
  pass





objek = C()

objek.method_A()
objek.method_B()
# Out:
# ini adalah method A
# ini adalah method B
