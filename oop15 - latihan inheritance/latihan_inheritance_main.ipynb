# %% [markdown]
# ### **OOP Kelas Terbuka #15.2 - Latihan Inheritance**

# %%
from latihan_inheritace_hero import HeroIntelligent,HeroStrength

lina = HeroIntelligent('lina')
slardar = HeroStrength('slardar')

lina.show_info()
slardar.show_info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from latihan_inheritace_hero import HeroIntelligent,HeroStrength
#       3 lina = HeroIntelligent('lina')
#       4 slardar = HeroStrength('slardar')
#
# ModuleNotFoundError: No module named 'latihan_inheritace_hero'
