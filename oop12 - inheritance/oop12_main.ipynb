# %% [markdown]
# ### **OOP Kelas Terbuka #12 - Pendahuluan Inheritance**

# %%
# mewariskan class

class Hero:

    # propertie
    

    def __init__(self,name,health):
        self.name = name
        self.healt = health


class Hero_intelligent(Hero):
    pass


class Hero_stength(Hero):
    pass


lina = Hero('lina',100)
balmond = Hero_intelligent('balmond', 50)
axe = Hero_stength('axe',200)

# %%
print(lina.name)
print(balmond.name)
print(axe.name)
# Out:
# lina
# balmond
# axe
